# %% [markdown]
# # Lab 7.1 - Building a classifier
#
# In this lab, you will download a set of free drum sounds available from [https://www.mediafire.com/file/7q81baqf23ybz7x/dubstep_empire_drum_kit.zip/file](https://www.mediafire.com/file/7q81baqf23ybz7x/dubstep_empire_drum_kit.zip/file) and build a classifier.

# %% [markdown]
# #### Problem 1 - Download and extract the drums sounds from the link provided above.

# %%
# %matplotlib inline
from pathlib import Path
import numpy as np, scipy, matplotlib.pyplot as plt, sklearn, urllib, IPython.display as ipd
import pandas as pd
import librosa, librosa.display
plt.rcParams['figure.figsize'] = (15, 5) # Set default plot size
import seaborn as sns

# %%
wgit()

# %%
Snares_sounds = [
    librosa.load(p)[0] for p in Path('/Dubstep Empire Drum Kit/Snares*.wav')
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-af4a85904d2f> in <module>
#       1 Snares_sounds = [
# ----> 2     librosa.load(p)[0] for p in Path('/Dubstep Empire Drum Kit/Snares*.wav')
#       3 ]
#
# TypeError: 'PosixPath' object is not iterable

# %%
Snares_sounds = [
    librosa.load(p)[0] for p in Path('/Users/pc7482yh/Documents/Dsci 330/Sounds_Files/Dubstep Empire Drum Kit/Snares_*.wav')
]
Kicks_sounds = [
    librosa.load(p)[0] for p in Path('/Users/pc7482yh/Documents/Dsci 330/Sounds_Files/Dubstep Empire Drum Kit/Kicks_*.wav')
]
Crash_sounds = [
    librosa.load(p)[0] for p in Path('/Users/pc7482yh/Documents/Dsci 330/Sounds_Files/Dubstep Empire Drum Kit/Crashes_*.wav')
]
Claps_sounds = [
    librosa.load(p)[0] for p in Path('/Users/pc7482yh/Documents/Dsci 330/Sounds_Files/Dubstep Empire Drum Kit/Claps_*.wav')
]

# %% [markdown]
# #### Problem 2 - Load the Snares and Kicks tracks and extract features.
#
# Be sure to extract at least four features, which might include [Energy and RMSE](https://musicinformationretrieval.com/energy.html), [Zero Crossing Rate](https://musicinformationretrieval.com/zcr.html) and/or any of the [spectral features](https://musicinformationretrieval.com/spectral_features.html)

# %%
Snare_sounds = [
    librosa.load(p)[0] for p in Path().glob('Dubstep Empire Drum Kit/Snares/Snare*.wav')
]

# %%
Kick_sounds = [
    librosa.load(p)[0] for p in Path().glob('Dubstep Empire Drum Kit/Kicks/Kick*.wav')
]

# %%
Kick_sounds = Kick_sounds[:415]

# %%
def extract_features(signal):
    return (
        librosa.feature.zero_crossing_rate(signal)[0, 0],
        librosa.feature.spectral_centroid(signal)[0, 0],
        librosa.feature.rms(signal)[0,0],
        librosa.feature.spectral_contrast(signal)[0, 0]

    )

# %%
kick_zcr, kick_spec_cent, kick_rms, kick_contrast = zip(*np.array([extract_features(x) for x in Kick_sounds]))
snare_zcr, snare_spec_cent, snare_rms, snare_contrast = zip(*np.array([extract_features(x) for x in Snare_sounds]))

# %%
drum_samples = pd.DataFrame({'type': 415*['kick'] + 415*['snare']
                           ,'zcr' : np.concatenate((kick_zcr, snare_zcr))
                           ,'spec_cent' : np.concatenate((kick_spec_cent, snare_spec_cent))
                           ,'rms' : np.concatenate((kick_rms, snare_rms))
                           ,'contrast' : np.concatenate((kick_contrast, snare_contrast))
                           })

# %% [markdown]
# #### Problem 3 - Make plots of the feature space
#
# Before building the classifier, you should make various plots of the feature space using [Seaborn pairplot](https://pythonbasics.org/seaborn-pairplot/)

# %%
assert sns.__version__ == '0.11.0', "Run: conda install -c anaconda seaborn"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-56-bfd6dfd3b7aa> in <module>
# ----> 1 assert sns.__version__ == '0.11.0', "Run: conda install -c anaconda seaborn"
#
# AssertionError: Run: conda install -c anaconda seaborn

# %%
import seaborn

# %%
sns.pairplot(drum_samples, hue="type")

# %% [markdown]
# #### Problem 4 - Train and Validate a Classifier
#
# You can use any classifier that you prefer, from logistic regression (as seen in STAT 310 and Lecture 7.3) or other classifiers that you might have learned about in DSCI 425.

# %%
scaler = sklearn.preprocessing.MinMaxScaler(feature_range=(-1, 1))
drum_samples[['zcr', 'spec_cent','rms','contrast']] = scaler.fit_transform(drum_samples[['zcr', 'spec_cent','rms','contrast']])

# %%
drum_samples[['zcr', 'spec_cent','rms','contrast']].describe()
# Out:
#               zcr   spec_cent         rms    contrast
# count  830.000000  830.000000  830.000000  830.000000
# mean    -0.612009   -0.274203   -0.016590   -0.293042
# std      0.407636    0.450778    0.380991    0.293766
# min     -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -0.954733   -0.670155   -0.264896   -0.487924
# 50%     -0.759259   -0.274243   -0.001399   -0.329548
# 75%     -0.379630    0.052414    0.256869   -0.134036
# max      1.000000    1.000000    1.000000    1.000000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split 

data_train, data_test, labels_train, labels_test = train_test_split(drum_samples[["zcr", "spec_cent",'rms','contrast']],drum_samples.type, test_size=0.3)

# %%
LRC = LogisticRegression()
LRC.fit(data_train, labels_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted = LRC.predict(data_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(labels_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         kick       0.89      0.96      0.92       126
#        snare       0.96      0.88      0.92       123
#
#     accuracy                           0.92       249
#    macro avg       0.92      0.92      0.92       249
# weighted avg       0.92      0.92      0.92       249

# %%
confusion_matrix(predicted, labels_test)
# Out:
# array([[121,  15],
#        [  5, 108]])

# %%
# Out:
# 'kick'

# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# Problem 5

# %%
import sklearn
import sklearn.metrics

# %%
sklearn.__version__
# Out:
# '0.22.1'

# %%
dir(sklearn.metrics)
# Out:
# ['ConfusionMatrixDisplay',
#  'PrecisionRecallDisplay',
#  'RocCurveDisplay',
#  'SCORERS',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_classification',
#  '_pairwise_fast',
#  '_plot',
#  '_ranking',
#  '_regression',
#  '_scorer',
#  'accuracy_score',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'auc',
#  'average_precision_score',
#  'balanced_accuracy_score',
#  'brier_score_loss',
#  'calinski_harabasz_score',
#  'calinski_harabaz_score',
#  'check_scoring',
#  'classification_report',
#  'cluster',
#  'cohen_kappa_score',
#  'completeness_score',
#  'confusion_matrix',
#  'consensus_score',
#  'coverage_error',
#  'davies_bouldin_score',
#  'dcg_score',
#  'euclidean_distances',
#  'explained_variance_score',
#  'f1_score',
#  'fbeta_score',
#  'fowlkes_mallows_score',
#  'get_scorer',
#  'hamming_loss',
#  'hinge_loss',
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
y_pred = LRC.predict(data_test)
cm = confusion_matrix(labels_test, y_pred)

cm_display = ConfusionMatrixDisplay(cm, display_labels= {"Kick","Snare"}).plot()

# %%
y_score = LRC.decision_function(data_test)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from sklearn import metrics
roc_auc = metrics.auc(fpr,tpr)
y_score = LRC.decision_function(data_test)

fpr, tpr, _ = roc_curve(labels_test, y_score, pos_label=LRC.classes_[1])
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc = roc_auc, estimator_name = "Estimator").plot()

# %%
Binary = [1 if line == 'Kick' else 0 for line in predicted]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import average_precision_score

average_precision = average_precision_score(Binary,y_score)
prec, recall, _ = precision_recall_curve(labels_test, y_score,
                                         pos_label=LRC.classes_[1])
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall,average_precision = average_precision,
                                   estimator_name ="Estmator").plot()

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))

roc_display.plot(ax=ax1)
pr_display.plot(ax=ax2)
plt.show()
